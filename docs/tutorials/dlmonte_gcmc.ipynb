# %% [markdown]
# # Automating `DL_MONTE` equation of state calculations with `simtask`

# %% [markdown]
# ## Introduction

# %% [markdown]
# `simtask` is a Python package for automating complex tasks involving multiple simulations. Here we introduce the package and provide an example illustrating how it could be used. The example involves calculating the energy and density of the Lennard-Jones fluid using grand-canonical Monte Carlo, via the program `DL_MONTE`, for various temperatures *automatically*. The user specifies which temperatures are to be examined, links `simtask` to the relevant `DL_MONTE` executable, and then sets the `simtask` machinery in motion. The result is that plots of energy and density vs. temperature, along with associated statistical uncertainties and taking into account the equilibration time of the simulation, are generated without any input from the user.

# %% [markdown]
# ## How does `simtask` work?

# %% [markdown]
# We now briefly describe the key features of `simtask` with the aim of elucidating how it works. The `simtask.task` module is the heart of the package. This contains the two key Python classes, `Task` and `TaskInterface`.
#
# `Task` - This is the base class corresponding to a simulation 'task', i.e. something you want to do via simulation. E.g. in the example below the 'task' is to evaluate the energy and density via grand-canonical Monte Carlo simulation. `Task` is an abstract class in the sense that it does nothing. It is subclasses of `Task` which correspond to different possible tasks, and contain code for performing these tasks. For instance the `Measurement` class is a subclass of `Task` which calculates one or more observables at a given set of thermodynamic conditions. This is used in our example below.
#
# The code for `Task` subclasses for performing simulation tasks is *general*; it is not specific to a simulation program, e.g. `DL_MONTE`. This is achieved by `Task` subclasses drawing only upon functions within the `TaskInterface` class for simulation-program-specific code. These functions constitute common things one may wish to do during a task (e.g. copy input files to a new directory, run a simulation in that directory, extract the energy from the output files of a directory), common things which can be combinedf into complex tasks. To enable `simtask` to be used with a given simulation program, one must write a subclass of `TaskInterface` which overloads the functions in `TaskInterface` with functions which are appropriate for that simulation code. For instance, `DLMonteInterface` is the subclass of `TaskInterface` which contains functions appropriate for the simulation program `DL_MONTE`. To perform a task in conjunction with `DL_MONTE`, the relevant `Task` subclass, e.g. `Measurement`, simply 'links' to the `DLMonteInterface`, which results in `Measurement` calling the `DL_MONTE`-specific functions for the common things during its invocation.
#
# This set-up separates the code pertaining to the task one is interested in performing from the code specific to the simulation program one will use to perform that task. `Task` subclasses will in principle work for *any* simulation program which has an existing `TaskInterface`. Conversely, simulation programs which have an existing `TaskInterface` will work for any future `Task` subclasses.

# %% [markdown]
# ## Preliminaries
#
# ### Installing and setting up `simtask`
#
# `simtask` can be obtained from ...

# %% [markdown]
# Once `simtask` has been installed, the Python environment must be configured so that `simtask` can be 'seen' by Python scripts and modules which wish to utilise the package. There are a number of ways in which this can be achieved. One is to manually change the list of directories which Python searches for packages and modules *within* Python. We will employ this approach here.

# %%
import sys
import os

# You will need to set SIMTASK_HOME appropriately for your local system. 
# Note that SIMTASK_HOME should be the directory ABOVE the directory 'simtask' 
# containing the source code, i.e. the files __init__.py, analysis.py, task.py, etc.
# Rather confusingly this directory might also be called 'simtask', as is the case
# here: '/home/tom/Work/Code_workspace/simtask/simtask' contains the source code.
SIMTASK_HOME = "/home/tom/Work/Code_workspace/simtask"

# Set the search path to the SIMTASK_HOME directory
sys.path.append( SIMTASK_HOME )

# %% [markdown]
# The alternative approach is to alter the shell variable `PYTHONPATH`, which contains a list of directories in which to look for Python packages to be imported. To use `simtask`, it is prudent to set `PYTHONPATH` to the directory containing the package, i.e. the directory stored in the `SIMTASK_HOME` variable in the above code snippet. The following shell command (or whatever equivalent is appropriate for your local system) does this:
#
# ```
# bash> SIMTASK_HOME="/home/tom/Work/Code_workspace/simtask"
# bash> export PYTHONPATH=$PYTHONPATH:$SIMTASK_HOME
# ```

# %% [markdown]
# Once `simtask` has been obtained and the Python environment has been configured appropriately, simtask can then be imported from within a Python script, and hence is ready to use.

# %%
import simtask

# %% [markdown]
# ### Dependencies for the example: `DL_MONTE` and `htk`

# %% [markdown]
# Below we use `simtask` to perform Monte Carlo simulations by interfacing simtask with the general-purpose Monte Carlo program `DL_MONTE`. Therefore `DL_MONTE` is a prerequisite for the examples below. However `simtask` also requires a further Python package, `htk`, which is distributed alongslide `DL_MONTE`, in order to interface with `DL_MONTE`. `htk` contains a Python interface for launching `DL_MONTE` simulations and manipulating `DL_MONTE` input and output files, functionality which is drawn upon by `simtask`.

# %% [markdown]
# See https://www.ccp5.ac.uk/DL_MONTE and links therein for details regarding how to obtain `DL_MONTE` and `htk`.

# %% [markdown]
# ### Installing and setting up the dependencies

# %% [markdown]
# `DL_MONTE` can be installed as described in the manual and the website where it is distributed.
#
# Similarly to as described above for `simtask`, the Python search directory for modules and packages must be set up so that `htk` can be 'seen'. As we did before for `simtask`, we elect to modify the search path within Python, though of course one could achieve the same result by modifying the shell variable `PYTHONPATH` as described above.

# %%
# You will need to set HTK_HOME appropriately for your local system. 
# Note that HTK_HOME should be the directory ABOVE the directory 'htk' 
# containing the package source code, i.e. the files __init__.py, histogram.py, 
# task.py, etc. Rather confusingly this directory might also be called 'htk', 
# as is the case here: '/home/tom/Work/Code_workspace/DL_MONTE_2_dev/dlmonte2/htk/htk' 
# contains the source code.
HTK_HOME = "/home/tom/Work/Code_workspace/DL_MONTE_2_dev/dlmonte2/htk"

# Set the search path to the 'HTK_HOME directory
sys.path.append( HTK_HOME )

# %% [markdown]
# ## Example 1: Energy and density of Lennard-Jones fluid at a given $\mu$ and $T$

# %% [markdown]
# We are now ready to begin the examples. The ultimate aim is to use `simtask` to calculate the energy and density, with associated uncertainties, of the Lennard-Jones fluid for a range of temperatures $T$ at a given chemical potential $\mu$. However we first consider the problem of evaluating these physical quantities at a *single* temperature; in Example 2 later we consider multiple temperatures.
#
# More specifically, we will use `simtask.measurement` to perform back-to-back grand-canonical Monte Carlo simulations with `DL_MONTE` until one of two criteria are met: 1) the energy and density (in fact, the mean number of particles in the system) are evaluated to a specified *precision*; 2) a threshold number of back-to-back simulations have been performed. Note that by 'back-to-back' we mean that the next simulation begins in the configuration where the previous simulation ended.
#
# To perform a standard grand-canonical `DL_MONTE` simulation three `DL_MONTE` input files are required, `CONTROL`, `CONFIG` and `FIELD`. The relevant files can be found in the directory housing this notebook. A fuller account of the significance of the contents of the input files can be found elsewhere, e.g. the `DL_MONTE` user manual. We discuss the contents of these files only briefly here. Moreover we do not provide here an account of grand-canonical Monte Carlo or Monte Carlo simulation methodology, further details of which can be found elsewhere. We assume the reader has a basic understanding of grand-canonical Monte Carlo and how to run grand-canonical simulations in `DL_MONTE`.

# %% [markdown]
# ### Simulation details
#
# The input files CONTROL, CONFIG and FIELD correspond to a grand-canonical Monte Carlo simulation of the Lennard-Jones fluid as follows. The reduced temperature is $T^*=1.55112$ and the thermodynamic activity is $z=0.04$, where $T^*\equiv k_BT/\epsilon$, $z\equiv\exp(\mu/(k_BT))$, and $\epsilon$ denotes the well depth of the Lennard-Jones potential. Note that the $T^*$ considered is above the critical temeprature (which is $T_c^*=1.326$). The system is a cube with sides of length $10\sigma$, where $\sigma$ is the interparticle separation at which the Lennard-Jones is zero. The potential is truncated at a distance of $2.5\sigma$, and no tail corrections are applied. The Monte Carlo move-set is comprised only of insertion and deletion moves; no translation moves were applied. Finally, the length of the simulation is 120,000 moves. (Note however that back-to-back simulations will be performed; hence considerably more moves than 120,000 will be used in total).

# %% [markdown]
# ### Configuring the output of `simtask`

# %% [markdown]
# We will now describe the `simtask` Python commands required to perform the task at hand. First of all we should import the relevant `simtask` modules. We also import the `logging` module (a standard library module), since `simtask` uses this module to control its output. The aim of `simtask` is to perform a complicated task involving multiple simulations. During such a task, `simtask` outputs information, via the `logging` module, regarding the progress of the task for the benefit of the user. `logging` enables the 'level' of output to be controlled. For debugging one would typically desire more information to be output; for very long tasks one would typically want a more succint description of the progress of the task. This is all covered by the below code snippet.

# %%
import logging

import simtask.dlmonteinterface as interface
import simtask.measurement as measurement            # IS ALL OF THIS REALLY NEEDED?
import simtask.analysis as analysis
import simtask.task as task

# Set up the logger, which determines the nature of information output by the 
# machinery in the 'simtask' package. The line below results in logging 
# information being output to stdout

handler = logging.StreamHandler()

# Below we set up the 'logger' in simtask.measurement, to determine the nature 
# of output when the 'measurement' module is used (see below). Replacing 
# 'logging.INFO' with 'logging.DEBUG' below results in more information being 
# output by the logger. Using 'logging.WARNING' results in less information 
# being output: only 'warnings'

measurement.logger.setLevel(logging.INFO)
measurement.logger.addHandler(handler)

# %% [markdown]
# ### Linking to the `DL_MONTE` executable

# %% [markdown]
# We now set up the relevant `TaskInterface` object, which tells the low-level machinery in `simtask` which simulation program will be used to perform the simulations, and how to perform various jobs specific to that program, e.g. extracting the energy from output files created by the program. In this case we use `DL_MONTE` to perform our simulations; thus the `TaskInterface` class we will use is `DLMonteInterface` (`DLMonteInterface` is a subclass of `TaskInterface`; see above). The code below creates a new `DLMonteInterface` object, which is linked to the `DL_MONTE` relevant executable. Later this object will be 'linked' to the relevant `Task` object before the task is performed.

# %%
# The line below creates a DL_MONTE-specific interface. Note that the interface 
# must know the location of the DL_MONTE executable - which is specified as the 
# argument to the DLMonteInterface constructor.
# You will have to adapt the location of the executable to suit your local system.

interface = interface.DLMonteInterface("/home/tom/Work/Code_workspace/DL_MONTE_2_dev_2/dlmonte2/bin/DLMONTE-SRL.X")

# %% [markdown]
# ### Setting up the `Measurement` object

# %% [markdown]
# We will use the `Measurement` class to automate the task of calculating the energy and number of molecules for various given chemical potentials.  We will set up a `Measurement` object, `m`, and then begin the task with the command
#
# ```python
# m.run()
# ```

# %% [markdown]
# #### Task observables
#
# The `Measurement` constructor requires a list of `Observable` objects (see below), which represent the physical quantities to be tracked during the task. We are interested in the energy and number of particles. Below we create a list `observables` accordingly.

# %%
energy_obs = task.Observable( ("energy",) )
nmol_obs = task.Observable( ("nmol",0) )
observables = [ energy_obs, nmol_obs ]

# %% [markdown]
# Note that the nature of `Observable` objects may vary between simulation codes. For `DL_MONTE` only observables corresponding to variables output periodically in the `YAMLDATA` file are currently supported. For a variable 'foo' specified in the `YAMLDATA` file the corresponding `Observable` object is returned by the command
#
# ```python
# task.Observable( ("foo",) )
# ```
#
# Note the essential comma after `"foo"`! For a variable in `YAMLDATA` which is an array (e.g., 'nmol'), the observable corresponding to the `n`th element in the array is returned by the command
#
# ```python
# task.Observable( ("foo",n-1) )
# ```
#
# See the code snippet above: `energy_obs` corresponds to the 'energy' variable in `YAMLDATA`, and `nmol_obs` corresponds to the 1st element in the 'nmol' array in `YAMLDATA` (which in fact is the number of molecules belonging to the 1st molecular species).

# %% [markdown]
# #### Termination criteria
#
# The `Measurement` class will perform back-to-back simulations until one of a number of customisable criteria have been met. The criteria are determined by the arguments passed to the constructor of the `Measurement` object. For now we apply two criteria. The first is that the energy is evaluated to a precision of 0.2 (energy units), i.e. the back-to-back simulations are terminated if the statistical uncertainty in the energy is less than this precision. The second criterion is that the number of back-to-back simulations does not exceed 20. The below code creates a `Measurement` object with the aforementioned criteria. Moreover we set the name of the directory in which the simulations are to be performed as `fixedprecision`.

# %%
# A dictionary is used to specify the threshold precisions to apply to the observables. Here we only
# specify a threshold precision for the energy observable: the simulations will terminate when the energy is
# determined to an uncertainty less than 0.2 (energy units). Note that there is no entry in the dictionary
# corresponding to the 'nmol' observable. The significance of this is that there is no threshold precision
# for this observable.

precisions = { energy_obs : 0.2 }

# Set up the relevant Measurement object - which will actually perform the simulations and data analysis.
# Note that all the simulations and output files pertaining to analysis will be created in the directory
# 'fixedprecision' (via the 'outputdir' argument), and that we will impose a threshold precision on the
# energy as implied by the dictionary 'precisions' described above. Furthermore, we specify that no more
# than 20 simulations will ever be performed (via the 'maxsims' argument)

m = measurement.Measurement(interface, observables, maxsims=20, precisions=precisions, outputdir='fixedprecision')

# %% [markdown]
# ### Running the task
#
# As mentioned above, the task is invoked via the command
#
# ```python
# m.run()
# ```
#
# Note that when this is called, information is generated and output to stdout at a level set earlier in the discussion pertaining to the `logging` module.

# %%
# Remove the old directory 'fixedprecision', if it exists, before running the task:
# the task will not run if the directory already exists; it will not be overwritten.

import shutil

if os.path.exists('fixedprecision'):
    shutil.rmtree('fixedprecision')


# Run the task

m.run()
# Out:
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedprecision/sim_1' for simulation...
# Running simulation in 'fixedprecision/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 4.11268841227
#   correlation time = 2.01515972449
#   calculated block size = 21
# Calculating block averages...
#   number of blocks found = 57
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -16.2003129454
#   std. error from block averages = 0.50669571669
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 3.82245684356
#   correlation time = 1.86680081247
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 63
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 48.3065998329
#   std. error from block averages = 0.626692757283
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedprecision/sim_2' for simulation...
# Running simulation in 'fixedprecision/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 3.79178078759
#   correlation time = 1.85108931642
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 126
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -15.7719478007
#   std. error from block averages = 0.32364224482
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 3.26942733787
#   correlation time = 1.58239821314
#   calculated block size = 16
# Calculating block averages...
#   number of blocks found = 150
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 47.9408333333
#   std. error from block averages = 0.376127241817
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedprecision/sim_3' for simulation...
# Running simulation in 'fixedprecision/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 3.60356624899
#   correlation time = 1.75454253406
#   calculated block size = 18
# Calculating block averages...
#   number of blocks found = 200
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -15.7665285078
#   std. error from block averages = 0.250239200668
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 3.14117787941
#   correlation time = 1.51601479197
#   calculated block size = 16
# Calculating block averages...
#   number of blocks found = 225
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 47.9411111111
#   std. error from block averages = 0.29853757852
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 4 of max. 20...
#
# Setting up directory 'fixedprecision/sim_4' for simulation...
# Running simulation in 'fixedprecision/sim_4'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 4800
#   statistical inefficiency = 3.73707811361
#   correlation time = 1.82305585948
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 252
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.3200514804
#   mean from block averages = -15.7761103145
#   std. error from block averages = 0.26061347283
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 4800
#   statistical inefficiency = 3.22262847682
#   correlation time = 1.55819718
#   calculated block size = 16
# Calculating block averages...
#   number of blocks found = 300
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.15288380855
#   mean from block averages = 47.939375
#   std. error from block averages = 0.286430986518
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 5 of max. 20...
#
# Setting up directory 'fixedprecision/sim_5' for simulation...
# Running simulation in 'fixedprecision/sim_5'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 6000
#   statistical inefficiency = 3.73497164326
#   correlation time = 1.82197593352
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 315
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.3405056768
#   mean from block averages = -15.7954235444
#   std. error from block averages = 0.231965931301
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 6000
#   statistical inefficiency = 3.19922358262
#   correlation time = 1.546084291
#   calculated block size = 16
# Calculating block averages...
#   number of blocks found = 375
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.15230230806
#   mean from block averages = 47.9813333333
#   std. error from block averages = 0.256280288399
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 6 of max. 20...
#
# Setting up directory 'fixedprecision/sim_6' for simulation...
# Running simulation in 'fixedprecision/sim_6'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 7200
#   statistical inefficiency = 3.6978894989
#   correlation time = 1.80295970864
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 378
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -15.8365957845
#   std. error from block averages = 0.185283586456
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 7200
#   statistical inefficiency = 3.19016438168
#   correlation time = 1.54139406693
#   calculated block size = 16
# Calculating block averages...
#   number of blocks found = 450
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 48.0029166667
#   std. error from block averages = 0.215951545956
# Analysis complete
#
# Checking end-of-task criteria...
# Threshold precision for std. error of observable 'energy' reached
# Precision threshold reached for all observables
#
#
# Completed measurement task

# %% [markdown]
# ### Analysing the output
#
# During the task the simulations are performed in subdirectories of the directory `fixedprecision` earmarked as the workspace for the task. The first simulation is performed in subdirectory `sim_1`, the second in `sim_2`, etc. The task involved 6 simulations before the task was terminated on account of the threshold energy being reached. Thus within `fixedprecision` there are thus 6 subdirectories, one corresponding to each simulation. Moreover there are two files, `energy_converge.dat` and `nmol_0_converge.dat`. These contain plots of the observables and their uncertainties obtained after each simulation: the first column in each file corresponds to the simulation number, the second to the mean value of the observable, and the third to the uncertainty. Note that data is pooled from all simulations up to that point in order to come up with the mean and uncertainty. Furthermore the mean and uncertainty are calculated only using post-equilibration data: an algorithm is used to detect when the system has equilibrated, and data obtained before that is ignored in calculating the mean and uncertainty. Details of how the mean and uncertainty are calculated, and how equilibration is detected, is beyond the scope of this document; see the source code for details.

# %% [markdown]
# PLOT THE ENERGY AND NMOL VS simulation number...

# %% [markdown]
# ## Example 2: Energy and density of Lennard-Jones fluid at a given $\mu$ vs. $T$

# %% [markdown]
# Example 1 demonstrated how `simtask` could be used to calculate the value and uncertainty of an observable automatically at a given set of thermodynamic conditions: the energy and density was calculated at a specified chemical potential and temperature. We will now go further, automating the calculation of the energy and density at *many* temperatures.
# The relevant `simtask` class is `MeasurementSweep`, which performs sets of simulations similar to that performed by `Measurement` at a list of different *control parameters*.
#
# Similarly to `Measurement`, to invoke the task corresponding to a `MeasurementSweep` object `sweep` the command is
#
# ```python
# sweep.run()
# ```
#
# However, first one must create the object `sweep`, parameterised appropriately for the task at hand.

# %% [markdown]
# ### Setting up the Measurement object
#
# First of all we must make a *template* `Measurement` object which will determine the nature of the calculations of energy and density at each temperature: the calculations at each temperature will track the same observables, and have the same termination criteria, as that of the template `Measurement` object. We make a template with the same observables and `TaskInterface` object (pertaining to `DL_MONTE`) as before. However this time we will use slightly different termination criteria. Instead of using the precision of the energy as a termination criterion, we will impose a maximum time of 30s to the task (i.e. if 30s has elapsed, then no further simulations will be performed beyond the current one). Thus the template `Measurement` object is created as follows.

# %%
measurement_template = measurement.Measurement(interface, observables, maxsims=20, maxtime=30)

# %% [markdown]
# Note that a maximum number of simulations of 20 is still a termination criterion, as it was in Example 1.
#
# The next step is to create a list of control parameters - in this case temperature - to examine.

# %%
temperatures = [8000,9000,10000,11000,12000,13000,14000,15000,16000,17000]

# %% [markdown]
# Finally we create the `MeasurementSweep` object `sweep` which will actually perform all the simulations and data analysis. The following command achieves this. Note that the list of control parameters is passed to the argument `paramvalues`. Note also that a string `"temperature"` has been passed to the argument `param`, which is the name of the control parameter. The result is that the `DLMonteInterface` object `interface`, which will create and modify `DL_MONTE` input files during the task, 'knows' to treat the temperature as a control parameter during the task. More specifically, in order to modify the input files appropriately for the next control parameter to be considered, it will search for the keyword `"temperature"` in the `DL_MONTE` input file `CONTROL`, and then modify the value of the temperature next to that keyword. Finally, we should mention that the name of the directory in which all simulations are to be performed is set to `fixedtimesweep`.

# %%
sweep = measurement.MeasurementSweep(param="temperature", paramvalues=temperatures,
                                     measurement_template=measurement_template, outputdir="fixedtimesweep")

# %% [markdown]
# ### Running the task
#
# As mentioned above, the task is invoked via the command
#
# ```python
# sweep.run()
# ```
#
# Note that when this is called, information is generated and output to stdout at a level set earlier in the discussion pertaining to the `logging` module.
#
# Since we are considering 10 temperatures, and have imposed a time limit of 30 s for all simulations at a given temperature, we expect that the whole task should take about 300s = 5min to perform.

# %%
# Remove the old directory 'fixedprecision', if it exists, before running the task:
# the task will not run if the directory already exists; it will not be overwritten.

if os.path.exists('fixedtimesweep'):
    shutil.rmtree('fixedtimesweep')

# Run the task
    
sweep.run()
# Out:
# Beginning measurement sweep task...
#
#
# Beginning measurement for control parameter value 8000...
#
# Setting up directory 'fixedtimesweep/param_8000' for control parameter value 8000...
# Running measurement for control parameter 8000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_8000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_8000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 248.252656236
#   correlation time = 124.125656756
#   calculated block size = 1242
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 189.083999807
#   correlation time = 94.5411184543
#   calculated block size = 946
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# /home/tom/Work/Code_workspace/simtask/simtask/analysis.py:213: RuntimeWarning: invalid value encountered in divide
#   autocorr = np.correlate(yshifted, yshifted, "full") / (len(y)*var)
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 622.540169133
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_8000/sim_2' for simulation...
# Running simulation in 'fixedtimesweep/param_8000/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 428.91310649
#   correlation time = 214.456164665
#   calculated block size = 2145
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -2659.8977659
#   std. error from block averages = nan
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 314.547589897
#   correlation time = 157.273265085
#   calculated block size = 1573
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 654.959313414
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_8000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_8000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 593.461583867
#   correlation time = 296.730511095
#   calculated block size = 2968
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -2769.06048436
#   std. error from block averages = nan
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 421.825111684
#   correlation time = 210.912160733
#   calculated block size = 2110
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 669.157819905
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 39.69384408s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 8000
#
#
# Extracting mean and standard error for all observables for control parameter 8000...
#
# Observable 'energy' was deemed equilibrated during measurement
# Final result for observable:
#   mean = -2769.06048436
#   standard error = nan
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 669.157819905
#   standard error = nan
#
# Completed extraction of mean and standard error for control parameter 8000
#
#
# Beginning measurement for control parameter value 9000...
#
# Setting up directory 'fixedtimesweep/param_9000' for control parameter value 9000...
# Running measurement for control parameter 9000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_9000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_9000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 253.446486025
#   correlation time = 126.722585409
#   calculated block size = 1268
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 184.482950576
#   correlation time = 92.240571855
#   calculated block size = 923
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 593.388949079
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_9000/sim_2' for simulation...
# Running simulation in 'fixedtimesweep/param_9000/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 450.273375721
#   correlation time = 225.136317715
#   calculated block size = 2252
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -2610.89530326
#   std. error from block averages = nan
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 312.502196242
#   correlation time = 156.25056479
#   calculated block size = 1563
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 632.913627639
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_9000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_9000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 570.168925577
#   correlation time = 285.084170477
#   calculated block size = 2851
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -2695.25567131
#   std. error from block averages = nan
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 382.268479825
#   correlation time = 191.133803918
#   calculated block size = 1912
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 644.508368201
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 38.8714010715s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 9000
#
#
# Extracting mean and standard error for all observables for control parameter 9000...
#
# Observable 'energy' was deemed equilibrated during measurement
# Final result for observable:
#   mean = -2695.25567131
#   standard error = nan
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 644.508368201
#   standard error = nan
#
# Completed extraction of mean and standard error for control parameter 9000
#
#
# Beginning measurement for control parameter value 10000...
#
# Setting up directory 'fixedtimesweep/param_10000' for control parameter value 10000...
# Running measurement for control parameter 10000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_10000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_10000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 263.000249086
#   correlation time = 131.499490828
#   calculated block size = 1315
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 203.921171127
#   correlation time = 101.959768249
#   calculated block size = 1020
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 580.107843137
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_10000/sim_2' for simulation...
# Running simulation in 'fixedtimesweep/param_10000/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 418.394930462
#   correlation time = 209.197066883
#   calculated block size = 2092
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -2496.00286748
#   std. error from block averages = nan
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 294.65299047
#   correlation time = 147.325929596
#   calculated block size = 1474
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 609.495929444
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_10000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_10000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 580.973498612
#   correlation time = 290.486462431
#   calculated block size = 2905
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -2631.03164316
#   std. error from block averages = nan
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 383.129906464
#   correlation time = 191.564518218
#   calculated block size = 1916
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 624.649791232
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 38.1878190041s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 10000
#
#
# Extracting mean and standard error for all observables for control parameter 10000...
#
# Observable 'energy' was deemed equilibrated during measurement
# Final result for observable:
#   mean = -2631.03164316
#   standard error = nan
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 624.649791232
#   standard error = nan
#
# Completed extraction of mean and standard error for control parameter 10000
#
#
# Beginning measurement for control parameter value 11000...
#
# Setting up directory 'fixedtimesweep/param_11000' for control parameter value 11000...
# Running measurement for control parameter 11000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_11000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_11000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 402.142936038
#   correlation time = 201.071053572
#   calculated block size = 2011
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 364.557186886
#   correlation time = 182.278136266
#   calculated block size = 1823
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_11000/sim_2' for simulation...
# Running simulation in 'fixedtimesweep/param_11000/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 605.929468373
#   correlation time = 302.964459127
#   calculated block size = 3030
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 489.990533109
#   correlation time = 244.994926412
#   calculated block size = 2450
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_11000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_11000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 803.547786468
#   correlation time = 401.77368582
#   calculated block size = 4018
# Calculating block averages...
#   number of blocks found = 0
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Cannot calculate mean: we need >= 1 post-equlibration block
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 609.351209237
#   correlation time = 304.675331103
#   calculated block size = 3047
# Calculating block averages...
#   number of blocks found = 1
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Cannot calculate standard error: we need >= 2 post-equilibration blocks
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 601.169346899
#   std. error from block averages = nan
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 37.2562570572s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 11000
#
#
# Extracting mean and standard error for all observables for control parameter 11000...
#
# Observable 'energy' was not deemed equilibrated during measurement: bypassing extraction...
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 601.169346899
#   standard error = nan
#
# Completed extraction of mean and standard error for control parameter 11000
#
#
# Beginning measurement for control parameter value 12000...
#
# Setting up directory 'fixedtimesweep/param_12000' for control parameter value 12000...
# Running measurement for control parameter 12000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_12000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_12000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 77.503371256
#   correlation time = 38.7495350884
#   calculated block size = 388
# Calculating block averages...
#   number of blocks found = 3
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -60.1746146159
#   std. error from block averages = 9.94552339396
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 60.2543494681
#   correlation time = 30.1244084788
#   calculated block size = 302
# Calculating block averages...
#   number of blocks found = 3
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 82.2604856512
#   std. error from block averages = 6.19202306082
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_12000/sim_2' for simulation...
# Running simulation in 'fixedtimesweep/param_12000/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 62.7988625899
#   correlation time = 31.3967771396
#   calculated block size = 314
# Calculating block averages...
#   number of blocks found = 7
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -58.2745820233
#   std. error from block averages = 5.00884230017
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 46.83388494
#   correlation time = 23.4133833603
#   calculated block size = 235
# Calculating block averages...
#   number of blocks found = 10
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 80.8561702128
#   std. error from block averages = 3.71818344128
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_12000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_12000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 70.5672263061
#   correlation time = 35.2812512125
#   calculated block size = 353
# Calculating block averages...
#   number of blocks found = 10
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -57.3701804566
#   std. error from block averages = 3.87789185015
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 54.4392691591
#   correlation time = 27.2165727885
#   calculated block size = 273
# Calculating block averages...
#   number of blocks found = 13
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 80.5378979994
#   std. error from block averages = 2.58450609241
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 4 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_12000/sim_4' for simulation...
# Running simulation in 'fixedtimesweep/param_12000/sim_4'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 4800
#   statistical inefficiency = 59.1771787535
#   correlation time = 29.5857727612
#   calculated block size = 296
# Calculating block averages...
#   number of blocks found = 16
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -57.6750721767
#   std. error from block averages = 3.3777195792
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 4800
#   statistical inefficiency = 43.973416678
#   correlation time = 21.9829176475
#   calculated block size = 220
# Calculating block averages...
#   number of blocks found = 21
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 80.6573593074
#   std. error from block averages = 2.0438625113
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 30.0681989193s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 12000
#
#
# Extracting mean and standard error for all observables for control parameter 12000...
#
# Observable 'energy' was deemed equilibrated during measurement
# Final result for observable:
#   mean = -57.6750721767
#   standard error = 3.3777195792
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 80.6573593074
#   standard error = 2.0438625113
#
# Completed extraction of mean and standard error for control parameter 12000
#
#
# Beginning measurement for control parameter value 13000...
#
# Setting up directory 'fixedtimesweep/param_13000' for control parameter value 13000...
# Running measurement for control parameter 13000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_13000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_13000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 11.187797341
#   correlation time = 5.57896961548
#   calculated block size = 56
# Calculating block averages...
#   number of blocks found = 21
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -35.583106898
#   std. error from block averages = 1.36778372771
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 8.56928037542
#   correlation time = 4.26511973129
#   calculated block size = 43
# Calculating block averages...
#   number of blocks found = 27
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.24975224784
#   mean from block averages = 65.6976744186
#   std. error from block averages = 1.12393876482
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_13000/sim_2' for simulation...
# Running simulation in 'fixedtimesweep/param_13000/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 11.9341339602
#   correlation time = 5.95307519161
#   calculated block size = 60
# Calculating block averages...
#   number of blocks found = 40
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -35.0007884513
#   std. error from block averages = 0.996013078259
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 8.92891861667
#   correlation time = 4.44573051996
#   calculated block size = 45
# Calculating block averages...
#   number of blocks found = 53
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 65.0922431866
#   std. error from block averages = 0.893352564297
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_13000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_13000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 13.0197622019
#   correlation time = 6.49705984781
#   calculated block size = 65
# Calculating block averages...
#   number of blocks found = 55
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -35.3304578882
#   std. error from block averages = 1.13539356149
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 9.92975603723
#   correlation time = 4.94804781339
#   calculated block size = 50
# Calculating block averages...
#   number of blocks found = 72
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 65.2561111111
#   std. error from block averages = 0.816504884136
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 4 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_13000/sim_4' for simulation...
# Running simulation in 'fixedtimesweep/param_13000/sim_4'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 4800
#   statistical inefficiency = 13.4466508461
#   correlation time = 6.71091242984
#   calculated block size = 68
# Calculating block averages...
#   number of blocks found = 70
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -35.5816684356
#   std. error from block averages = 0.918322035901
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 4800
#   statistical inefficiency = 10.5705206048
#   correlation time = 5.26945537547
#   calculated block size = 53
# Calculating block averages...
#   number of blocks found = 90
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 65.5188679245
#   std. error from block averages = 0.712610874262
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 5 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_13000/sim_5' for simulation...
# Running simulation in 'fixedtimesweep/param_13000/sim_5'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 6000
#   statistical inefficiency = 14.8961729522
#   correlation time = 7.43688444218
#   calculated block size = 75
# Calculating block averages...
#   number of blocks found = 80
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -35.3580427652
#   std. error from block averages = 0.895160032412
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 6000
#   statistical inefficiency = 10.6715403686
#   correlation time = 5.32011558014
#   calculated block size = 54
# Calculating block averages...
#   number of blocks found = 111
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 65.4039039039
#   std. error from block averages = 0.596489121438
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 36.4724001884s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 13000
#
#
# Extracting mean and standard error for all observables for control parameter 13000...
#
# Observable 'energy' was deemed equilibrated during measurement
# Final result for observable:
#   mean = -35.3580427652
#   standard error = 0.895160032412
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 65.4039039039
#   standard error = 0.596489121438
#
# Completed extraction of mean and standard error for control parameter 13000
#
#
# Beginning measurement for control parameter value 14000...
#
# Setting up directory 'fixedtimesweep/param_14000' for control parameter value 14000...
# Running measurement for control parameter 14000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_14000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_14000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 10.4873060433
#   correlation time = 5.22772207593
#   calculated block size = 53
# Calculating block averages...
#   number of blocks found = 22
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 0.939998568276
#   mean from block averages = -27.3263609829
#   std. error from block averages = 1.28690840905
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 6.05802401286
#   correlation time = 3.00129747535
#   calculated block size = 31
# Calculating block averages...
#   number of blocks found = 38
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.41083578731
#   mean from block averages = 58.7045840407
#   std. error from block averages = 1.07838237972
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# ...
#   std. error from block averages = 0.395301177316
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 3.65811997298
#   correlation time = 1.78255397151
#   calculated block size = 18
# Calculating block averages...
#   number of blocks found = 133
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 51.5756056809
#   std. error from block averages = 0.4036166805
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_16000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_16000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 4.95901852252
#   correlation time = 2.4455280431
#   calculated block size = 25
# Calculating block averages...
#   number of blocks found = 144
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -19.3073701984
#   std. error from block averages = 0.352642441234
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 3.81684067173
#   correlation time = 1.86392482737
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 189
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 51.5126705653
#   std. error from block averages = 0.36531656024
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 4 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_16000/sim_4' for simulation...
# Running simulation in 'fixedtimesweep/param_16000/sim_4'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 4800
#   statistical inefficiency = 4.86209195542
#   correlation time = 2.39637169294
#   calculated block size = 24
# Calculating block averages...
#   number of blocks found = 200
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -19.3200982906
#   std. error from block averages = 0.296913669802
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 4800
#   statistical inefficiency = 3.78017377088
#   correlation time = 1.8451428226
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 252
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 51.61946533
#   std. error from block averages = 0.310323147322
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 5 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_16000/sim_5' for simulation...
# Running simulation in 'fixedtimesweep/param_16000/sim_5'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 6000
#   statistical inefficiency = 4.84813171982
#   correlation time = 2.38928939007
#   calculated block size = 24
# Calculating block averages...
#   number of blocks found = 250
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -19.3778192575
#   std. error from block averages = 0.2725806265
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 6000
#   statistical inefficiency = 3.75386083697
#   correlation time = 1.83165873727
#   calculated block size = 19
# Calculating block averages...
#   number of blocks found = 315
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 51.6917293233
#   std. error from block averages = 0.28041491889
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 36.8730509281s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 16000
#
#
# Extracting mean and standard error for all observables for control parameter 16000...
#
# Observable 'energy' was deemed equilibrated during measurement
# Final result for observable:
#   mean = -19.3778192575
#   standard error = 0.2725806265
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 51.6917293233
#   standard error = 0.28041491889
#
# Completed extraction of mean and standard error for control parameter 16000
#
#
# Beginning measurement for control parameter value 17000...
#
# Setting up directory 'fixedtimesweep/param_17000' for control parameter value 17000...
# Running measurement for control parameter 17000...
#
# Beginning measurement task...
#
#
# Beginning simulations...
#
#
# On simulation 1 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_17000/sim_1' for simulation...
# Running simulation in 'fixedtimesweep/param_17000/sim_1'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 1200
#   statistical inefficiency = 4.5053638317
#   correlation time = 2.21519002566
#   calculated block size = 23
# Calculating block averages...
#   number of blocks found = 52
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -17.234607689
#   std. error from block averages = 0.457111011619
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 1200
#   statistical inefficiency = 3.00790679517
#   correlation time = 1.44680881579
#   calculated block size = 15
# Calculating block averages...
#   number of blocks found = 80
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 49.3825
#   std. error from block averages = 0.504658892034
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 2 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_17000/sim_2' for simulation...
# Running simulation in 'fixedtimesweep/param_17000/sim_2'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 2400
#   statistical inefficiency = 3.46641917199
#   correlation time = 1.68401302053
#   calculated block size = 17
# Calculating block averages...
#   number of blocks found = 141
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -17.2900176844
#   std. error from block averages = 0.338837050972
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 2400
#   statistical inefficiency = 3.07638018894
#   correlation time = 1.48239660959
#   calculated block size = 15
# Calculating block averages...
#   number of blocks found = 160
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 49.5875
#   std. error from block averages = 0.367206537923
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 3 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_17000/sim_3' for simulation...
# Running simulation in 'fixedtimesweep/param_17000/sim_3'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 3600
#   statistical inefficiency = 3.53990612603
#   correlation time = 1.72182471101
#   calculated block size = 18
# Calculating block averages...
#   number of blocks found = 200
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -17.2471884813
#   std. error from block averages = 0.266067367638
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 3600
#   statistical inefficiency = 3.11684810027
#   correlation time = 1.50339856216
#   calculated block size = 16
# Calculating block averages...
#   number of blocks found = 225
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 49.4636111111
#   std. error from block averages = 0.310245291821
# Analysis complete
#
# Checking end-of-task criteria...
# End-of-task criteria not yet reached. Proceeding to next simulation...
#
#
# On simulation 4 of max. 20...
#
# Setting up directory 'fixedtimesweep/param_17000/sim_4' for simulation...
# Running simulation in 'fixedtimesweep/param_17000/sim_4'...
# Simulation complete
#
# Extracting data for observable 'energy'...
# Extraction complete
# Analysing time series for observable 'energy'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'energy':
#   number of data points = 4800
#   statistical inefficiency = 4.11031730908
#   correlation time = 2.01394962868
#   calculated block size = 21
# Calculating block averages...
#   number of blocks found = 228
# Analysing block averages for observable 'energy' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = -17.3352018779
#   std. error from block averages = 0.252689273878
#
# Extracting data for observable 'nmol_0'...
# Extraction complete
# Analysing time series for observable 'nmol_0'...
# Bypassing equilibration test: equilibration assumed from outset
# System is deemed equilibrated
#   equilibration time = 0
# Deducing blocks to use for block averaging...
# Results of post-equilibration time series analysis for observable 'nmol_0':
#   number of data points = 4800
#   statistical inefficiency = 3.39104845172
#   correlation time = 1.64518040936
#   calculated block size = 17
# Calculating block averages...
#   number of blocks found = 282
# Analysing block averages for observable 'nmol_0' (for mean and standard error)...
# Results of analysis of block averages:
#   statistical inefficiency of block averages = 1.0
#   mean from block averages = 49.6378806842
#   std. error from block averages = 0.28674377983
# Analysis complete
#
# Checking end-of-task criteria...
# Task time threshold of 30s exceeded:
#   elapsed time = 32.9382779598s
#
#
# Completed measurement task
#
#
# Completed measurement for control parameter 17000
#
#
# Extracting mean and standard error for all observables for control parameter 17000...
#
# Observable 'energy' was deemed equilibrated during measurement
# Final result for observable:
#   mean = -17.3352018779
#   standard error = 0.252689273878
#
# Observable 'nmol_0' was deemed equilibrated during measurement
# Final result for observable:
#   mean = 49.6378806842
#   standard error = 0.28674377983
#
# Completed extraction of mean and standard error for control parameter 17000
#
#
# Measurement sweep task complete

# %% [markdown]
# ### Analysing the output
#
# During the task the simulations are performed in subdirectories of the directory `fixedtimesweep` earmarked as the workspace for the task. The simulations corresponding to control parameter (i.e. temperature) 8000 were performed in the subdirectory `param_8000`, the simulations corresponding to control parameter 9000 were performed in subdirectory `param_9000`, etc. There were 10 control parameters considered, and hence there are 10 such `param_` subdirectories. Moreover there are two files, `energy_sweep.dat` and `nmol_0_sweep.dat`. These contain plots of the observables and their uncertainties obtained at each control parameter vs. control parameter: the first column in each file corresponds to the control parameter, the second to the mean value of the observable, and the third to the uncertainty. As with Example 1, the post-equilibration data from the multiple simulations performed at each control parameter are pooled in order to come up with the final mean and uncertainty.
#
# Note that some of the uncertainties have value `nan`. This signifies that not enough post-equilibration data was gathered given the constraints (i.e. the finite time limit of 30s we imposed to examine each temperature) for an uncertainty to be calculated. Similar would apply to mean values if that were the case.
